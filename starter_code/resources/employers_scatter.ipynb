# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
GDpath = "resources/employers_clean.csv"
WLBpath="resources/Work-Life-Balance-2022.csv"

employers_df=pd.read_csv(GDpath, encoding = "ISO-8859-1")
WLB_df=pd.read_csv(WLBpath, encoding = "ISO-8859-1")

employers_df=employers_df.rename(columns={"HQ_CITY":"City","COUNTRY/TERRITORY":"Country","GLASSDOOR_OVERALL_RATING":"Glassdoor Rating"})
employers_df
employers_df.to_csv('employers_df.csv',index=False, header = True)

employers_df
# Out:
#     RANK                   NAME     TICKER  \
# 0      1    Samsung Electronics  005930.KS
# 1      2              Microsoft       MSFT
# 2      3                    IBM        IBM
# 3      4               Alphabet       GOOG
# 4      5                  Apple       AAPL
# ..   ...                    ...        ...
# 95    96             Mastercard         MA
# 96    97  Electricite de France     EDF.PA
# 97    98                Verbund     VER.VI
# 98    99              Panasonic     6572.T
# 99   100               Emirates       none
#
#                                            INDUSTRIES               Country  \
# 0   Semiconductors, Electronics, Electrical Engine...            South Kore
# 1                   IT, Internet, Software & Services         United States
# 2   Semiconductors, Electronics, Electrical Engine...         United States
# 3                   IT, Internet, Software & Services         United States
# 4   Semiconductors, Electronics, Electrical Engine...         United States
# ..                                                ...                   ...
# 95                     Banking and Financial Services         United States
# 96                                          Utilities                France
# 97                                          Utilities               Austria
# 98                         Engineering, Manufacturing                 Japan
# 99                       Transportation and Logistics  United Arab Emirates
#
#    EMPLOYEES  Glassdoor Rating           City
# 0    266,673               3.8          Suwon
# 1    221,000               4.4        Redmond
# 2    250,000               4.2         Armonk
# 3    156,500               4.5  Mountain View
# 4    154,000               4.1      Cupertino
# ..       ...               ...            ...
# 95    24,000               4.3       Purchase
# 96   167,157               4.0          Paris
# 97     3,184               4.7         Vienna
# 98   240,198               3.8         Kadoma
# 99    85,219               4.1          Dubai
#
# [100 rows x 8 columns]

# %%
plt.scatter(employers_df['Glassdoor Rating'],employers_df['RANK'])
plt.show()

# %%
WLB_df.head()
# Out:
#    2022 2021        City      Country Remote Jobs Overworked Population  \
# 0     1    2        Oslo       Norway      41.72%                11.20%
# 1     2    -        Bern  Switzerland      44.86%                11.40%
# 2     3    1    Helsinki      Finland      38.92%                12.70%
# 3     4    3      Zurich  Switzerland      44.86%                11.90%
# 4     5    5  Copenhagen      Denmark      41.42%                10.50%
#
#    Minimum Vacations Offered (Days) Vacations Taken (Days)  Unemployment  \
# 0                                25                     25          94.7
# 1                                20                     25          99.8
# 2                                25                     30          89.3
# 3                                20                     25          99.2
# 4                                25                     28          94.8
#
#   Multiple Jobholders  ... Healthcare Access to Mental Healthcare  \
# 0               9.10%  ...      100.0                        85.0
# 1               7.60%  ...       99.6                        78.6
# 2               6.30%  ...       96.7                        73.0
# 3               7.60%  ...       99.2                        78.6
# 4               7.60%  ...       94.8                        77.6
#
#    Inclusivity & Tolerance  Affordability  Happiness, Culture & Leisure  \
# 0                     93.2           59.4                          88.8
# 1                     94.6           69.9                         100.0
# 2                     93.9           65.0                          96.3
# 3                     87.5           71.6                          91.5
# 4                     95.2           65.3                          92.5
#
#    City Safety  Outdoor Spaces  Air Quality  Wellness and Fitness  TOTAL SCORE
# 0         86.5            95.6         97.5                  65.7       100.00
# 1         91.8            87.1        100.0                  69.1        99.46
# 2         94.9            86.0         97.0                  68.3        99.24
# 3         92.8            84.0         96.2                  68.7        96.33
# 4         95.7            75.5         95.1                  66.3        96.21
#
# [5 rows x 24 columns]

# %%
employers_places_df=pd.merge(employers_df, WLB_df, on="City",how="inner")
employers_places_cleaned=employers_places_df[['RANK','NAME','TICKER','Country_x','EMPLOYEES','Glassdoor Rating','City','TOTAL SCORE']]
employers_places_cleaned=employers_places_cleaned.rename(columns={"Country_x":"Country","TOTAL SCORE":"Work-Life balance score"})
employers_places_cleaned.sort_values(by='RANK')
# Out:
#     RANK                     NAME     TICKER               Country  EMPLOYEES  \
# 0      6          Delta Air Lines        DAL         United States     80,000
# 3      9       Southwest Airlines        LUV         United States     55,093
# 4     13                BMW Group     BMW.DE               Germany    118,909
# 9     14                   Amazon       AMZN         United States  1,608,000
# 5     19       Fraunhofer Society       none               Germany     30,028
# 10    21                    Rolex       none           Switzerland     14,000
# 12    25      Mercedes-Benz Group     MBG.DE               Germany    172,425
# 13    28                   Safran     SAF.PA                France     76,800
# 17    29                   Pfizer        PFE         United States     79,000
# 1     32                Coca-Cola         KO         United States     79,000
# 19    33             Armani Group       none                 Italy      8,000
# 22    34              Honda Motor     7267.T                 Japan    211,374
# 6     38                  Siemens     SIE.DE               Germany    303,000
# 14    48                   Sanofi     SAN.PA                France     95,000
# 25    49     Rolls-Royce Holdings       RR.L        United Kingdom     44,000
# 27    51                   Target        TGT         United States    450,000
# 2     52           The Home Depot         HD         United States     30,000
# 28    53             Hyatt Hotels          H         United States    164,000
# 29    54                   Boeing         BA         United States    142,000
# 30    56                  Shopify       SHOP                Canada     10,000
# 18    57        Colgate-Palmolive         CL         United States     33,800
# 7     60         MTU Aero Engines     MTX.DE               Germany     10,000
# 26    61                   Chanel       none        United Kingdom     28,500
# 31    62  Raymond James Financial        RJF         United States     15,000
# 32    66                   Oracle       ORCL         United States    133,000
# 8     70            Wacker Chemie     WCH.DE               Germany     14,400
# 20    72                    Prada    1913.HK                 Italy     13,140
# 33    73           General Motors         GM         United States    157,000
# 34    74             T Rowe Price       TROW         United States      7,529
# 35    78                  Viatris       VTRS         United States     37,000
# 23    80      Mitsubishi Electric     8058.T                 Japan    145,696
# 21    81                  Pirelli    PIRC.MI                 Italy     30,690
# 11    83         Kempinski Hotels       none           Switzerland     22,500
# 15    84              Naval Group       none                France     17,373
# 36    85                    Naver  035420.KS           South Korea      4,696
# 37    86   Meritz Financial Group  008560.KS           South Korea         20
# 24    88                     Sony       SONY                 Japan    108,900
# 38    93                 SK Group  034730.KS           South Korea    117,590
# 39    95                 DBS Bank     D05.SI             Singapore     33,000
# 16    97    Electricite de France     EDF.PA                France    167,157
# 40    98                  Verbund     VER.VI               Austria      3,184
# 41   100                 Emirates       none  United Arab Emirates     85,219
#
#     Glassdoor Rating         City  Work-Life balance score
# 0                4.2      Atlanta                    84.06
# 3                4.4       Dallas                    81.74
# 4                4.2       Munich                    93.65
# 9                3.8      Seattle                    88.38
# 5                4.1       Munich                    93.65
# 10               3.9       Geneva                    95.82
# 12               3.9    Stuttgart                    93.79
# 13               3.8        Paris                    89.73
# 17               4.1     New York                    84.23
# 1                4.1      Atlanta                    84.06
# 19               3.7        Milan                    83.66
# 22               3.9        Tokyo                    92.47
# 6                4.1       Munich                    93.65
# 14               3.9        Paris                    89.73
# 25               4.0       London                    89.74
# 27               3.6  Minneapolis                    88.09
# 2                4.0      Atlanta                    84.06
# 28               4.0      Chicago                    82.92
# 29               3.8      Chicago                    82.92
# 30               3.7       Ottawa                    95.51
# 18               3.9     New York                    84.23
# 7                3.9       Munich                    93.65
# 26               3.9       London                    89.74
# 31               4.4      Toronto                    91.12
# 32               3.9       Austin                    83.67
# 8                4.0       Munich                    93.65
# 20               3.6        Milan                    83.66
# 33               4.0      Detroit                    80.36
# 34               3.8    Baltimore                    82.77
# 35               3.7   Pittsburgh                    83.63
# 23               3.9        Tokyo                    92.47
# 21               4.0        Milan                    83.66
# 11               3.9       Geneva                    95.82
# 15               3.8        Paris                    89.73
# 36               4.1        Seoul                    79.71
# 37               5.0        Seoul                    79.71
# 24               4.1        Tokyo                    92.47
# 38               3.7        Seoul                    79.71
# 39               3.9    Singapore                    85.66
# 16               4.0        Paris                    89.73
# 40               4.7       Vienna                    88.17
# 41               4.1        Dubai                    61.23

# %%
plt.scatter(employers_places_cleaned['Work-Life balance score'],employers_places_cleaned['RANK'])
plt.gca().invert_yaxis()
